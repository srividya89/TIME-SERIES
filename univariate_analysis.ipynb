# %%
import yfinance as yf
import pandas as pd

# Download Apple stock data
df = yf.download(
    "AAPL",
    start="2010-01-04",
    end="2020-11-21",
    auto_adjust=False
)

# Save to CSV
df.reset_index(inplace=True)
df.to_csv(r"C:\Users\Admin4\Downloads\AAPL_2010_2020_adjusted.csv", index=False)

print("CSV file created successfully!")
# Out:
# [*********************100%***********************]  1 of 1 completed
# CSV file created successfully!

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing the necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")


# Importing the data

data = pd.read_csv(r"C:\Users\Admin4\Downloads\AAPL_2010_2020_adjusted.csv")


data.head()
# Out:
#          Date           Adj Close              Close                High  \
# 0         NaN                AAPL               AAPL                AAPL
# 1  2010-01-04  6.4183831214904785  7.643214225769043   7.660714149475098
# 2  2010-01-05   6.429479598999023  7.656428813934326   7.699643135070801
# 3  2010-01-06   6.327212333679199  7.534643173217773    7.68678617477417
# 4  2010-01-07  6.3155131340026855  7.520713806152344  7.5714287757873535
#
#                   Low               Open     Volume
# 0                AAPL               AAPL       AAPL
# 1   7.585000038146973  7.622499942779541  493729600
# 2  7.6160712242126465  7.664286136627197  601904800
# 3   7.526785850524902  7.656428813934326  552160000
# 4   7.466071128845215             7.5625  477131200

# %%
data = data.iloc[1:].reset_index(drop=True)

# %%
data
# Out:
#             Date           Adj Close               Close                High  \
# 0     2010-01-04  6.4183831214904785   7.643214225769043   7.660714149475098
# 1     2010-01-05   6.429479598999023   7.656428813934326   7.699643135070801
# 2     2010-01-06   6.327212333679199   7.534643173217773    7.68678617477417
# 3     2010-01-07  6.3155131340026855   7.520713806152344  7.5714287757873535
# 4     2010-01-08   6.357499599456787   7.570713996887207  7.5714287757873535
# ...          ...                 ...                 ...                 ...
# 2737  2020-11-16   117.1063232421875  120.30000305175781  120.98999786376953
# 2738  2020-11-17    116.220458984375  119.38999938964844  120.66999816894531
# 2739  2020-11-18  114.89656829833984  118.02999877929688  119.81999969482422
# 2740  2020-11-19   115.4903793334961  118.63999938964844  119.05999755859375
# 2741  2020-11-20  114.22489166259766  117.33999633789062   118.7699966430664
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2742 entries, 0 to 2741
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2742 non-null   object
#  1   Adj Close  2742 non-null   object
#  2   Close      2742 non-null   object
#  3   High       2742 non-null   object
#  4   Low        2742 non-null   object
#  5   Open       2742 non-null   object
#  6   Volume     2742 non-null   object
# dtypes: object(7)
# memory usage: 150.1+ KB

# %%
data.describe()
# Out:
#               Date         Adj Close               Close  High  \
# count         2742              2742                2742  2742
# unique        2742              2704                2631  2607
# top     2010-01-04  26.6948184967041  24.905000686645508  40.0
# freq             1                 2                   3     3
#
#                        Low   Open     Volume
# count                 2742   2742       2742
# unique                2622   2630       2735
# top     24.577499389648438  18.75  146118800
# freq                     3      4          2

# %%
data.isnull().sum()
# Out:
# Date         0
# Adj Close    0
# Close        0
# High         0
# Low          0
# Open         0
# Volume       0
# dtype: int64

# %%
import datetime

# %%
date = []

# %%
data["Date"].dtype
# Out:
# dtype('O')

# %%
data["Date"] = pd.to_datetime(data["Date"])

# %%
data["Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
date = data["Date"].dt.strftime("%Y-%m-%d").tolist()

# %%
cols = ["Adj Close", "Close", "High", "Low", "Open", "Volume"]
data[cols] = data[cols].apply(pd.to_numeric, errors="coerce")

# %% [raw]
# #data = data.dropna() if any

# %%
len(date)
# Out:
# 2742

# %%
date
# Out:
# ['2010-01-04',
#  '2010-01-05',
#  '2010-01-06',
#  '2010-01-07',
#  '2010-01-08',
#  '2010-01-11',
#  '2010-01-12',
#  '2010-01-13',
#  '2010-01-14',
#  '2010-01-15',
#  '2010-01-19',
#  '2010-01-20',
#  '2010-01-21',
#  '2010-01-22',
#  '2010-01-25',
#  '2010-01-26',
#  '2010-01-27',
#  '2010-01-28',
#  '2010-01-29',
#  '2010-02-01',
#  '2010-02-02',
#  '2010-02-03',
#  '2010-02-04',
#  '2010-02-05',
#  '2010-02-08',
#  '2010-02-09',
#  '2010-02-10',
#  '2010-02-11',
#  '2010-02-12',
#  '2010-02-16',
#  '2010-02-17',
#  '2010-02-18',
#  '2010-02-19',
#  '2010-02-22',
#  '2010-02-23',
#  '2010-02-24',
#  '2010-02-25',
#  '2010-02-26',
#  '2010-03-01',
#  '2010-03-02',
#  '2010-03-03',
#  '2010-03-04',
#  '2010-03-05',
#  '2010-03-08',
#  '2010-03-09',
#  '2010-03-10',
#  '2010-03-11',
#  '2010-03-12',
#  '2010-03-15',
#  '2010-03-16',
#  '2010-03-17',
#  '2010-03-18',
#  '2010-03-19',
#  '2010-03-22',
#  '2010-03-23',
#  '2010-03-24',
#  '2010-03-25',
#  '2010-03-26',
# ...

# %%
data["date"]=date

# %%
data=data.drop(["Date"],axis=1)

# %%
data.head()
# Out:
#    Adj Close     Close      High       Low      Open     Volume        date
# 0   6.418383  7.643214  7.660714  7.585000  7.622500  493729600  2010-01-04
# 1   6.429480  7.656429  7.699643  7.616071  7.664286  601904800  2010-01-05
# 2   6.327212  7.534643  7.686786  7.526786  7.656429  552160000  2010-01-06
# 3   6.315513  7.520714  7.571429  7.466071  7.562500  477131200  2010-01-07
# 4   6.357500  7.570714  7.571429  7.466429  7.510714  447610800  2010-01-08

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2742 entries, 0 to 2741
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  2742 non-null   float64
#  1   Close      2742 non-null   float64
#  2   High       2742 non-null   float64
#  3   Low        2742 non-null   float64
#  4   Open       2742 non-null   float64
#  5   Volume     2742 non-null   int64
#  6   date       2742 non-null   object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 150.1+ KB

# %%
#changing date from object to date time data type
data["date"]=pd.to_datetime(data["date"])

# %%
#Checking missing dates logic
# total number of days in 10 years
total_days = (365 * 10) + (365 - 41) + (3 * 1) - 3
total_days
# Out:
# 3974

# %%
#Calculate missing dates
print("Total number of observations to be present in the data", total_days)
print("Actual number of observations in the data", len(data))
print("Missing dates from the actual data", total_days - len(data))
# Out:
# Total number of observations to be present in the data 3974
# Actual number of observations in the data 2742
# Missing dates from the actual data 1232

# %%
import datetime
import pandas as pd
import numpy as np

# %%
#define start and end date
start = datetime.datetime.strptime("04-01-2010", "%d-%m-%Y")
end = datetime.datetime.strptime("21-11-2020", "%d-%m-%Y")

# %%
#generate all dates between start and end
a = []

for x in range(0, (end - start).days):
    date_generated = start + datetime.timedelta(days=x)
    a.append(date_generated)

# %%
#convert list to DataFrame
total = pd.DataFrame(a, columns=["Date"])

# %%
#convert list to DataFrame
data1 = pd.DataFrame(a, columns=["Date"])
data1["Close"]=np.nan
data1.head()
# Out:
#         Date  Close
# 0 2010-01-04    NaN
# 1 2010-01-05    NaN
# 2 2010-01-06    NaN
# 3 2010-01-07    NaN
# 4 2010-01-08    NaN

# %%
data1.tail()
# Out:
#            Date  Close
# 3969 2020-11-16    NaN
# 3970 2020-11-17    NaN
# 3971 2020-11-18    NaN
# 3972 2020-11-19    NaN
# 3973 2020-11-20    NaN

# %% [markdown]
# we took close variable which is very important

# %%
#Updating the "Close" values in the new dataset
for i in range(0, len(data)):
    for j in range(0, len(data1)):
        if data.date[i] == data1.Date[j]:
            data1["Close"][j] = data["Close"][i]
            break

# %%
data1.head()
# Out:
#         Date     Close
# 0 2010-01-04  7.643214
# 1 2010-01-05  7.656429
# 2 2010-01-06  7.534643
# 3 2010-01-07  7.520714
# 4 2010-01-08  7.570714

# %%
data1.tail()
# Out:
#            Date       Close
# 3969 2020-11-16  120.300003
# 3970 2020-11-17  119.389999
# 3971 2020-11-18  118.029999
# 3972 2020-11-19  118.639999
# 3973 2020-11-20  117.339996

# %%
data1.isna().sum()
# Out:
# Date        0
# Close    1232
# dtype: int64

# %%
#Calculate missing dates
print("Total number of observations to be present in the data", total_days)
print("Actual number of observations in the data", len(data))
print("Missing dates from the actual data", total_days - len(data))
# Out:
# Total number of observations to be present in the data 3974
# Actual number of observations in the data 2742
# Missing dates from the actual data 1232

# %%
#selecting the date column as the index
data1=data1.set_index('Date')

# %%
data1.head()
# Out:
#                Close
# Date
# 2010-01-04  7.643214
# 2010-01-05  7.656429
# 2010-01-06  7.534643
# 2010-01-07  7.520714
# 2010-01-08  7.570714

# %%
#plotting the data
data1["Close"].plot(figsize=(15,8))
plt.title("Stock Close Price")
plt.show()

# %%
#impute missing values in gap in graph
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
sns.boxplot(data1['Close'])
plt.xlabel('Close')
plt.title('Histogram of Close')
plt.show()

# %%
#Interpolation for Missing Values
data2 = data1.interpolate(method='time')

# %%
data2.head()
# Out:
#                Close
# Date
# 2010-01-04  7.643214
# 2010-01-05  7.656429
# 2010-01-06  7.534643
# 2010-01-07  7.520714
# 2010-01-08  7.570714

# %%
# Plot interpolated values
data2.plot(figsize=(15, 7))
plt.show()

# %%
#Time Series Decomposition
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt

def seasonal_decompose_ts(x):
    decomposition = seasonal_decompose(x)

    trend = decomposition.trend
    seasonal = decomposition.seasonal
    residual = decomposition.resid

    plt.figure(figsize=(15, 6))

    plt.subplot(411)
    plt.plot(x, label='Original')
    plt.legend(loc='best')

    plt.subplot(412)
    plt.plot(trend, label='Trend')
    plt.legend(loc='best')

    plt.subplot(413)
    plt.plot(seasonal, label='Seasonal')
    plt.legend(loc='best')

    plt.subplot(414)
    plt.plot(residual, label='Residual')
    plt.legend(loc='best')

    plt.tight_layout()

# %%
seasonal_decompose_ts(data2['Close'])

# %%
#ADF Test (Stationarity Check)
from statsmodels.tsa.stattools import adfuller

# Defining a function for ADF test
def adfuller_test(sales):
    result = adfuller(sales)

    labels = [
        'ADF Test Statistic',
        'p-value',
        '#Lags Used',
        'Number of Observations Used'
    ]

    for value, label in zip(result, labels):
        print(label + ' : ' + str(value))

    if result[1] <= 0.05:
        print("The data is stationary")
    else:
        print("The data is not stationary")

# %%
adfuller_test(data2)
# Out:
# ADF Test Statistic : 1.9160253819498303
# p-value : 0.9985533699406058
# #Lags Used : 28
# Number of Observations Used : 3945
# The data is not stationary

# %%
adfuller_test(data2['Close'])
# Out:
# ADF Test Statistic : 1.9160253819498303
# p-value : 0.9985533699406058
# #Lags Used : 28
# Number of Observations Used : 3945
# The data is not stationary

# %%
# Plot the time series
data2.plot(figsize=(15, 7))

# Regular differencing (1st order)
data2_diff = data2.diff(periods=1)

# Removing NaN values created after differencing
data2_diff = data2_diff.dropna()

# Again testing using Dickey-Fuller test
adfuller_test(data2_diff)
# Out:
# ADF Test Statistic : -9.444007457171612
# p-value : 4.809730934678468e-16
# #Lags Used : 31
# Number of Observations Used : 3941
# The data is stationary

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# ACF and PACF plots
plt.figure(figsize=(15, 8))

# ACF plot
plt.subplot(211)
plot_acf(data2_diff, lags=30)
plt.title("ACF Plot")

# PACF plot
plt.subplot(212)
plot_pacf(data2_diff.dropna(), lags=30)
plt.title("PACF Plot")

plt.tight_layout()
plt.show()

# %% [raw]
# if data not differenced it will plot like below
# Why all ACF lags look the same height?
#
# Because your series is still highly correlated with itself at all lags.
#
# In simple words:
#
# The value today is very similar to yesterday, last week, last month, etc.
#
# That’s why all the vertical bars are almost the same and close to 1.0.
#
# 🔍 What ACF actually measures
#
# ACF at lag k =
# 👉 correlation between:
#
# X(t)  and  X(t − k)
#
#
# If your data has a strong trend, then:
#
# X(t) ≈ X(t−1)
#
# X(t) ≈ X(t−10)
#
# X(t) ≈ X(t−30)
#
# So correlation stays very high for every lag.
#
# That’s exactly what your plot shows.
#
# ⚠️ What this indicates
#
# This ACF plot means:
#
# ❌ Data is not stationary
# ❌ Strong trend present
# ❌ ARIMA cannot be applied yet
#
# This pattern is classic for stock price / financial data before differencing.
#
# ✅ Typical shapes
# 🔴 Non-stationary data (your plot)
#
# ACF values slowly decay
#
# All lags high
#
# Looks like a flat wall
#
# ➡️ Means trend exists
#
# 🟢 Stationary data (after differencing)
#
# ACF drops quickly
#
# Only first few lags significant
#
# Others fall inside blue region
#
# ➡️ Suitable for ARIMA
#
# ✅ What you must do next
#
# Apply first-order differencing:
#
# data_diff = data['Close'].diff().dropna()
#
#
# Then plot ACF again:
#
# from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
# import matplotlib.pyplot as plt
#
# plt.figure(figsize=(12,6))
# plot_acf(data_diff, lags=30)
# plt.show()
#
#
# Now you will see:
#
# Only few spikes
#
# Others near zero
#
# Proper ARIMA identification
#
# 🎯 Interview-ready explanation
#
# “When all ACF lags have similar high values, it indicates strong trend and non-stationarity. Differencing is required to remove trend before selecting AR and MA terms.”

# %% [markdown]
# we have p=1,d=1 and q=1 from acf and pacf plots

# %%
#AR model-ARIMA Model
from statsmodels.tsa.arima.model import ARIMA

# AR model building
model_ar = ARIMA(data2['Close'], order=(1, 1, 0))

# Fit the model
model_ar_fit = model_ar.fit()

# View model summary
model_ar_fit.summary()
# Out:
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                 3974
# Model:                 ARIMA(1, 1, 0)   Log Likelihood               -4026.259
# Date:                Mon, 19 Jan 2026   AIC                           8056.517
# ...

# %%
# Check AIC value
model_ar_fit.aic
# Out:
# np.float64(8056.517359066692)

# %%
# Model summary
model_ar_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                 3974
# Model:                 ARIMA(1, 1, 0)   Log Likelihood               -4026.259
# Date:                Mon, 19 Jan 2026   AIC                           8056.517
# Time:                        21:31:26   BIC                           8069.092
# Sample:                    01-04-2010   HQIC                          8060.976
#                          - 11-20-2020
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0268      0.005     -5.730      0.000      -0.036      -0.018
# sigma2         0.4444      0.002    230.189      0.000       0.441       0.448
# ...
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):            441860.75
# ...

# %%
# Predicting the values using the model
data2['forecast_ar'] = model_ar_fit.predict(
    start=3914,
    end=3974,
    dynamic=True
)

# %%
data2['forecast_ar']
# Out:
# Date
# 2010-01-04           NaN
# 2010-01-05           NaN
# 2010-01-06           NaN
# 2010-01-07           NaN
# 2010-01-08           NaN
#                  ...
# 2020-11-16    110.051852
# 2020-11-17    110.051852
# 2020-11-18    110.051852
# 2020-11-19    110.051852
# 2020-11-20    110.051852
# Name: forecast_ar, Length: 3974, dtype: float64

# %%
# Plot predicted values
data2[['Close', 'forecast_ar']].plot(figsize=(15, 7))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# here forecasted values came from stationary data without seasonnality so lets use sarimax model to induce seasonality

# %%
# Using SARIMAX model to account for seasonality
import statsmodels.api as sm
#AR model using SARIMAX

# %%
#induce seasonality using sarimax model 
# SARIMAX model
model1 = sm.tsa.statespace.SARIMAX(
    data2.Close,
    order=(1, 1, 0),
    seasonal_order=(1, 1, 0, 28)
)
#26,20,28 lags will have significant values
# Out:
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
# Fit the model
result = model1.fit()

# %%
# Forecast last 60 values
data2['forecast_sarimax'] = result.predict(
    start=3914,
    end=3974,
    dynamic=True
)

# %%
# Plot actual vs predicted values
data2[['Close', 'forecast_sarimax']][3700:].plot(figsize=(12, 8))
# Out:
# <Axes: xlabel='Date'>

# %%
# Model evaluation using RMSE
from sklearn.metrics import mean_squared_error
import numpy as np

RMSE_AR = np.sqrt(
    mean_squared_error(
        data2.Close[3914:3974],
        data2.forecast_sarimax[3914:3974]
    )
)

print("RMSE :", RMSE_AR)
# Out:
# RMSE : 5.630698376769281

# %%
#MA Model (ARIMA 0,1,1)
from statsmodels.tsa.arima.model import ARIMA

# MA model
model_ma = ARIMA(data2.Close, order=(0, 1, 1))

# Fit the model
model_ma_fit = model_ma.fit()
# Out:
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
# Check AIC value
model_ma_fit.aic
# Out:
# np.float64(8056.632125140081)

# %%
# Model summary
model_ma_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                 3974
# Model:                 ARIMA(0, 1, 1)   Log Likelihood               -4026.316
# Date:                Mon, 19 Jan 2026   AIC                           8056.632
# Time:                        21:54:28   BIC                           8069.207
# Sample:                    01-04-2010   HQIC                          8061.091
#                          - 11-20-2020
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.0257      0.005     -5.443      0.000      -0.035      -0.016
# sigma2         0.4444      0.002    230.263      0.000       0.441       0.448
# ...
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):            441420.97
# ...

# %%
#MA Forecast + SARIMAX
# Predicting the values using MA model
data2['forecast_ma'] = model_ma_fit.predict(
    start=3914,
    end=3974,
    dynamic=True
)

# %%
# Plot actual vs MA forecast
data2[['Close', 'forecast_ma']][3900:].plot(figsize=(15, 7))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# prediction is bad since its stationarity data which has trend and seasonaility.so now induce seasonality with SARIMAX model

# %%
# Using SARIMAX model to account for seasonality
import statsmodels.api as sm

# %%
# MA MODEL USING SARIMAX model
model2 = sm.tsa.statespace.SARIMAX(
    data2.Close,
    order=(0, 1, 1),
    seasonal_order=(1, 1, 1, 28)
)
# Out:
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
#SARIMAX Final Forecast & Evaluation
# Fit the SARIMAX model
result = model2.fit()

# %%
# Predict last 60 values
data2['forecast_sarimax'] = result.predict(
    start=3914,
    end=3974,
    dynamic=True
)

# %%
# Plot actual vs predicted values
data2[['Close', 'forecast_sarimax']][3700:].plot(figsize=(12, 8))
# Out:
# <Axes: xlabel='Date'>

# %%
# Evaluate model using RMSE
from sklearn.metrics import mean_squared_error
import numpy as np

RMSE_MA_SARIMA = np.sqrt(
    mean_squared_error(
        data2.Close[3914:3974],
        data2.forecast_sarimax[3914:3974]
    )
)

print("RMSE :", RMSE_MA_SARIMA)
# Out:
# RMSE : 3.8455235135859254

# %%
#ARIMA Model (1,1,1)
from statsmodels.tsa.arima.model import ARIMA

# ARIMA model
model_arima = ARIMA(data2.Close, order=(1, 1, 1))

# Fit the model
model_arima_fit = model_arima.fit()
# Out:
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
# Check AIC value
model_arima_fit.aic
# Out:
# np.float64(8057.444163700679)

# %%
# Model summary
model_arima_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                 3974
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -4025.722
# Date:                Mon, 19 Jan 2026   AIC                           8057.444
# Time:                        22:08:19   BIC                           8076.306
# Sample:                    01-04-2010   HQIC                          8064.132
#                          - 11-20-2020
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4370      0.131     -3.348      0.001      -0.693      -0.181
# ma.L1          0.4088      0.132      3.090      0.002       0.149       0.668
# sigma2         0.4442      0.002    226.594      0.000       0.440       0.448
# ...

# %%
# Predicting the values using ARIMA model
data2['forecast_arima'] = model_arima_fit.predict(
    start=3914,
    end=3974,
    dynamic=True
)

# %%
# Plot ARIMA forecast
data2[['Close', 'forecast_arima']][3700:].plot(figsize=(15, 7))
# Out:
# <Axes: xlabel='Date'>

# %%
#induce seasonality
# Using SARIMAX model to account for seasonality
import statsmodels.api as sm

# %%
# SARIMAX model with ARIMA order + seasonal order
model3 = sm.tsa.statespace.SARIMAX(
    data2.Close,
    order=(1, 1, 1),
    seasonal_order=(1, 1, 1, 28)
)
# Out:
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
# Fit the model
result = model3.fit()

# %%
# Predicting the values using ARIMA model
data2['forecast_sarimax'] = result.predict(
    start=3914,
    end=3974,
    dynamic=True
)

# %%
# Plot ARIMA forecast
data2[['Close', 'forecast_sarimax']][3700:].plot(figsize=(15, 7))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# even though it unable to catch up variations but it predicts mean value well.

# %%
# Evaluate model using RMSE
from sklearn.metrics import mean_squared_error
import numpy as np

RMSE_ARIMA_SARIMAX = np.sqrt(
    mean_squared_error(
        data2.Close[3914:3974],
        data2.forecast_sarimax[3914:3974]
    )
)

print("RMSE :", RMSE_ARIMA_SARIMAX)
# Out:
# RMSE : 3.8432773729455922

# %% [markdown]
# NOW LETS USE PREVIOUS DAY INTERPOLATION TECHNIQUE

# %% [raw]
# #Previous day imputation
# Why level=0 is used here?
# data3 = data1.reset_index(level=0)
#
# ✅ Short answer
#
# Because your Date is stored as the index, and you want to convert it back into a normal column.
#
# 🔹 What does level=0 mean?
#
# In pandas:
#
# level=0 → first index level
#
# level=1 → second index level (only if you have MultiIndex)
#
# In your case:
#
# Your dataset looks like this 👇
#
# Index (Date) | Close
# --------------------
# 2010-01-04   | 7.64
# 2010-01-05   | NaN
# 2010-01-06   | 7.53
#
#
# Here:
#
# Date is the index
#
# Index position = 0
#
# Hence:
#
# level=0  → Date index
#
# 🔹 Why do we need to reset the index?
#
# Because this code needs row-wise indexing 👇
#
# data3.Close[i - 1]
#
#
# This works only when:
#
# Data has integer index (0,1,2,3,...)
#
# ❌ It will NOT work if index is Date:
#
# data3.Close['2010-01-05' - 1]   ❌ impossible
#
#
# So we must convert Date index → normal column.
#
# That’s why we do:
#
# data1.reset_index(level=0)
#
# 🔹 What happens after reset_index?
#
# Before:
#
# Index = Date
#
#
# After:
#
# Date | Close
# 0
# 1
# 2
# 3
#
#
# Now this works perfectly:
#
# data3.Close[i - 1]
#
#
# because i is numeric.
#
# 🔹 Why not just write reset_index()?
#
# You can do this also 👇
#
# data3 = data1.reset_index()
#
#
# But your notebook uses:
#
# reset_index(level=0)
#
#
# because:
#
# It clearly specifies which index to reset
#
# Useful when dataset has multiple indexes (MultiIndex)
#
# Example:
#
# (level 0) Date
# (level 1) Company
#
#
# Then you can choose exactly which one to reset.
#
# ✅ Final simple meaning
# Code	Meaning
# level=0	First index (Date)
# Purpose	Convert index → column
# Needed	To access previous row using i-1
# Used in	Previous-day imputation
# 🔥 One-line interview answer:
#
# level=0 is used to reset the Date index into a column so that row-wise operations like previous-day imputation using i-1 can be performed.

# %%
# Create another dataset
data3 = data1.reset_index(level=0)

# Check missing values
data3.isna().sum()
# Out:
# Date        0
# Close    1232
# dtype: int64

# %%
# Imputing NA values with previous day data
x = data3[data3.Close.isna()]

for i in x.index:
    data3.Close[i] = data3.Close[i - 1]

# %%
# Set Date back as index
data3.set_index('Date', inplace=True)

# Plot data after imputation
data3.plot(figsize=(15, 7))
# Out:
# <Axes: xlabel='Date'>

# %%
#Checking stationarity

# %%
# ADF test
adfuller_test(data3)
# Out:
# ADF Test Statistic : 1.9682180038352672
# p-value : 0.9986302029601759
# #Lags Used : 24
# Number of Observations Used : 3949
# The data is not stationary

# %%
#Regular differencing (1st order)
# Differencing
data3_diff = data3.diff(periods=1)

# %%
# ADF test after differencing
adfuller_test(data3_diff.dropna())
# Out:
# ADF Test Statistic : -11.450184002866786
# p-value : 5.8841526384814504e-21
# #Lags Used : 23
# Number of Observations Used : 3949
# The data is stationary

# %%
data3_diff.plot(figsize=(15, 7))
# Out:
# <Axes: xlabel='Date'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15, 8))

ax1 = fig.add_subplot(211)
plot_acf(data3_diff.dropna(), lags=30, ax=ax1)

ax2 = fig.add_subplot(212)
plot_pacf(data3_diff.dropna(), lags=30, ax=ax2)

plt.show()

# %% [markdown]
# P=1,D=1,Q=1

# %%
# Using the SARIMAX model to account for seasonality
import statsmodels.api as sm

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
# Build SARIMAX model
model1 = sm.tsa.statespace.SARIMAX(
    data3.Close,
    order=(1, 1, 0),
    seasonal_order=(1, 1, 0, 28)
)
# Out:
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
# Fit the model
result = model1.fit()

# %%
# Predict last 60 days
data3['forecast_sarimax'] = result.predict(
    start=3914,
    end=3974,
    dynamic=True
)

# %%
# Plot actual vs predicted
data3[['Close', 'forecast_sarimax']][3700:].plot(figsize=(12, 8))
# Out:
# <Axes: xlabel='Date'>

# %%
# Evaluating the model
RMSE_AR = np.sqrt(
    mean_squared_error(
        data3.Close[3914:3974],
        data3.forecast_sarimax[3914:3974]
    )
)

print("RMSE :", RMSE_AR)
# Out:
# RMSE : 5.678829728389052

# %%
#MA Model
from statsmodels.tsa.arima.model import ARIMA

model_ma = ARIMA(data3.Close, order=(0, 1, 1))
model_ma_fit = model_ma.fit()
# Out:
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
# AIC value
model_ma_fit.aic
# Out:
# np.float64(8817.038172131597)

# %%
# Model summary
model_ma_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                 3974
# Model:                 ARIMA(0, 1, 1)   Log Likelihood               -4406.519
# Date:                Tue, 20 Jan 2026   AIC                           8817.038
# Time:                        07:48:17   BIC                           8829.613
# Sample:                    01-04-2010   HQIC                          8821.497
#                          - 11-20-2020
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.1237      0.006    -22.363      0.000      -0.135      -0.113
# sigma2         0.5381      0.002    227.165      0.000       0.533       0.543
# ...
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):            419436.71
# ...

# %%
# Predicting the values using the MA model
data3['forecast_ma'] = model_ma_fit.predict(
    start=3914,
    end=3974,
    dynamic=True
)

# %%
# Plot actual vs predicted
data3[['Close', 'forecast_ma']][3900:].plot(figsize=(15, 7))
# Out:
# <Axes: xlabel='Date'>

# %%
# Using the SARIMAX model to account for seasonality
import statsmodels.api as sm

# %%
model2 = sm.tsa.statespace.SARIMAX(
    data3.Close,
    order=(0, 1, 1),
    seasonal_order=(0, 1, 1, 28)
)
# Out:
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
# Fit the SARIMAX model
result = model2.fit()

# %%
# Predict last 60 days
data3['forecast_sarimax'] = result.predict(
    start=3914,
    end=3974,
    dynamic=True
)

# %%
# Plot actual vs predicted
data3[['Close', 'forecast_sarimax']][3700:].plot(figsize=(12, 8))
# Out:
# <Axes: xlabel='Date'>

# %%
# Evaluating the model
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
RMSE_MA_SARIMA = np.sqrt(
    mean_squared_error(
        data3.Close[3914:3974],
        data3.forecast_sarimax[3914:3974]
    )
)

print("RMSE :", RMSE_MA_SARIMA)
# Out:
# RMSE : 4.922775161603548

# %%
#ARIMA USING SARIMAX
# ARIMA Model
from statsmodels.tsa.arima.model import ARIMA

# %%
# Build ARIMA(1,1,1) model
model_arima = ARIMA(data3.Close, order=(1, 1, 1))
# Out:
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
# Fit the model
model_arima_fit = model_arima.fit()

# %%
# Check AIC value
model_arima_fit.aic
# Out:
# np.float64(8818.393137940344)

# %%
# Model summary
model_arima_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                 3974
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -4406.197
# Date:                Tue, 20 Jan 2026   AIC                           8818.393
# Time:                        08:01:01   BIC                           8837.255
# Sample:                    01-04-2010   HQIC                          8825.081
#                          - 11-20-2020
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0983      0.045     -2.203      0.028      -0.186      -0.011
# ma.L1         -0.0270      0.046     -0.592      0.554      -0.116       0.062
# sigma2         0.5380      0.002    220.898      0.000       0.533       0.543
# ...

# %% [markdown]
# p value which is <0.05is also called significant values

# %%
# Predicting the values using the model
data3['forecast_arima'] = model_arima_fit.predict(
    start=3914,
    end=3974,
    dynamic=True
)

# %%
# Plot actual vs predicted
data3[['Close', 'forecast_arima']][3700:].plot(figsize=(15, 7))
# Out:
# <Axes: xlabel='Date'>

# %%
#Using SARIMAX model to account for seasonality
import statsmodels.api as sm

# %%
# Build SARIMAX model
model3 = sm.tsa.statespace.SARIMAX(
    data3.Close,
    order=(1, 1, 1),
    seasonal_order=(1, 1, 1, 28)
)
# Out:
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin4\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
# Fit the SARIMAX model
result = model3.fit()

# %%
data3['forecast_sarimax'] = result.predict(
    start=3914,
    end=3974,
    dynamic=True
)

# %%
data3[['Close', 'forecast_sarimax']][3700:].plot(figsize=(12, 8))
# Out:
# <Axes: xlabel='Date'>

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
RMSE_ARIMA_SARIMA = np.sqrt(
    mean_squared_error(
        data3.Close[3914:3974],
        data3.forecast_sarimax[3914:3974]
    )
)

# %%
print("RMSE :", RMSE_ARIMA_SARIMA)
# Out:
# RMSE : 4.033586618184831

# %% [markdown]
# we built 3 models using time interpolation method and 3 models using previous day interpolation method

# %%
#Forecasting stock price for next 15 days
data3.tail()
# Out:
#                  Close  forecast_sarimax  forecast_ma  forecast_arima
# Date
# 2020-11-16  120.300003        116.714826   109.680082      109.710169
# 2020-11-17  119.389999        116.776522   109.680082      109.710169
# 2020-11-18  118.029999        117.178501   109.680082      109.710169
# 2020-11-19  118.639999        116.951875   109.680082      109.710169
# 2020-11-20  117.339996        118.045096   109.680082      109.710169

# %%
import datetime
import pandas as pd

# %%
start = datetime.datetime.strptime("21-11-2020", "%d-%m-%Y")
end   = datetime.datetime.strptime("05-12-2020", "%d-%m-%Y")

# %%
#Generate next 15 days dates
x = []

for i in range((end - start).days):
    date_generated = start + datetime.timedelta(days=i+1)
    x.append(date_generated)

# %%
#Create DataFrame for future dates
x = pd.DataFrame(x, columns=["Date"])
x.set_index("Date", inplace=True)

# %%
x.tail()
# Out:
# Empty DataFrame
# Columns: []
# Index: [2020-12-01 00:00:00, 2020-12-02 00:00:00, 2020-12-03 00:00:00, 2020-12-04 00:00:00, 2020-12-05 00:00:00]

# %%
#Concatenate future dates with original dataset
data3 = pd.concat([data3, x], axis=0)

# %%
data3.tail()
# Out:
#             Close  forecast_sarimax  forecast_ma  forecast_arima
# Date
# 2020-12-01    NaN               NaN          NaN             NaN
# 2020-12-02    NaN               NaN          NaN             NaN
# 2020-12-03    NaN               NaN          NaN             NaN
# 2020-12-04    NaN               NaN          NaN             NaN
# 2020-12-05    NaN               NaN          NaN             NaN

# %%
result = model3.fit()

# %%
#Predict future values (last 15 days)
data3['final_forecast'] = result.predict(
    start=3974,
    end=3989,
    dynamic=True
)

# %%
data3[['Close', 'final_forecast']][3980:].plot(figsize=(15, 8))
# Out:
# <Axes: xlabel='Date'>

# %%
data3['final_forecast'][3974:]
# Out:
# Date
# 2020-11-22    117.641311
# 2020-11-23    118.114568
# 2020-11-24    118.610326
# 2020-11-25    118.866238
# 2020-11-26    118.462791
# 2020-11-27    117.852775
# 2020-11-28    117.852774
# 2020-11-29    117.852774
# 2020-11-30    117.959950
# 2020-12-01    117.423599
# 2020-12-02    118.305852
# 2020-12-03    118.058431
# 2020-12-04    117.980907
# 2020-12-05    117.980907
# Name: final_forecast, dtype: float64

# %% [markdown]
# also try with VAR model for multivariate analysis using all variables of dataset

# %% [raw]
# Why level=0 is used here?
# data3 = data1.reset_index(level=0)
#
# ✅ Short answer
#
# Because your Date is stored as the index, and you want to convert it back into a normal column.
#
# 🔹 What does level=0 mean?
#
# In pandas:
#
# level=0 → first index level
#
# level=1 → second index level (only if you have MultiIndex)
#
# In your case:
#
# Your dataset looks like this 👇
#
# Index (Date) | Close
# --------------------
# 2010-01-04   | 7.64
# 2010-01-05   | NaN
# 2010-01-06   | 7.53
#
#
# Here:
#
# Date is the index
#
# Index position = 0
#
# Hence:
#
# level=0  → Date index
#
# 🔹 Why do we need to reset the index?
#
# Because this code needs row-wise indexing 👇
#
# data3.Close[i - 1]
#
#
# This works only when:
#
# Data has integer index (0,1,2,3,...)
#
# ❌ It will NOT work if index is Date:
#
# data3.Close['2010-01-05' - 1]   ❌ impossible
#
#
# So we must convert Date index → normal column.
#
# That’s why we do:
#
# data1.reset_index(level=0)
#
# 🔹 What happens after reset_index?
#
# Before:
#
# Index = Date
#
#
# After:
#
# Date | Close
# 0
# 1
# 2
# 3
#
#
# Now this works perfectly:
#
# data3.Close[i - 1]
#
#
# because i is numeric.
#
# 🔹 Why not just write reset_index()?
#
# You can do this also 👇
#
# data3 = data1.reset_index()
#
#
# But your notebook uses:
#
# reset_index(level=0)
#
#
# because:
#
# It clearly specifies which index to reset
#
# Useful when dataset has multiple indexes (MultiIndex)
#
# Example:
#
# (level 0) Date
# (level 1) Company
#
#
# Then you can choose exactly which one to reset.
#
# ✅ Final simple meaning
# Code	Meaning
# level=0	First index (Date)
# Purpose	Convert index → column
# Needed	To access previous row using i-1
# Used in	Previous-day imputation

# %% [raw]
# level=0 is used to reset the Date index into a column so that row-wise operations like previous-day imputation using i-1 can be performed.

# %% [markdown]
# 2. What is Bivariate Analysis?
# Simple definition (interview perfect):
#
# Bivariate analysis studies the relationship between two variables at a time.
#
# Example:
#
# Open vs Close
#
# High vs Low
#
# Volume vs Close
#
# Why we do bivariate analysis?
#
# To understand:
#
# ✔ How two variables move together
#
# ✔ Strength of relationship
#
# ✔ Direction (positive / negative)
#
# ✔ Dependency between variables
#
# This helps in:
#
# Feature selection
#
# Model building
#
# Understanding price behavior
#
# ✅ 3. Bivariate analysis for your stock dataset
#
# We will analyze:
#
# 1️⃣ Open vs Close
# 2️⃣ High vs Low
# 3️⃣ Volume vs Close
# 4️⃣ Correlation heatmap
